# %%
import numpy as np 

from astropy.table import Table

import matplotlib.pyplot as plt

import emcee
import chainconsumer
from chainconsumer import ChainConsumer, Chain

# %%
# hubble original

data = Table.read('../data/hubble.txt', format='ascii')
d, v = data['r'], data['v']
d_err = 0.1
plt.errorbar(d,v,xerr=d_err,fmt='o')
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
def lnprior(H0):
    if 0 < H0 < 1000:
        return 0.0
    return -np.inf

def model(H0, intercept, v):
    return v/H0 + intercept

def lnlike(H0, intercept, v, d, d_err):
    return -0.5 * np.sum((d-model(H0,intercept,v))**2 / d_err**2)

def lnprob(theta, v, d, d_err):
    H0, intercept = theta
    lp = lnprior(H0)
    if not np.isfinite(lp):
        return -np.inf
    return lp + lnlike(H0,intercept, v, d, d_err)

# %%
# sample with emcee
ndim, nwalkers = 2, 100
pos = np.array([500,0]) + 1e-4 * np.random.randn(100, 2)
sampler = emcee.EnsembleSampler(nwalkers, ndim, lnprob, args=(v, d,d_err))
burnin = sampler.run_mcmc(pos, 500, progress=True)
sampler.reset()
sampler.run_mcmc(burnin, 1000, progress=True);
# Out:
# 100%|██████████| 500/500 [00:02<00:00, 246.18it/s]
# 100%|██████████| 1000/1000 [00:03<00:00, 259.75it/s]

# %%
# chainconsumer

samples = sampler.get_chain(flat=True)
chain = Chain.from_emcee(sampler, ['H0','intercept'], "an emcee chain", discard=200, thin=2, color="indigo")
consumer = ChainConsumer().add_chain(chain)

fig = consumer.plotter.plot()

# %%
# plot posterior predictive model

# choose values

inds = np.random.choice(np.arange(samples.shape[0]), 50)
ds = np.linspace(0, 2.3, 100)

for ind in inds:
    H0 = samples[ind,0]
    intercept = samples[ind,1]

    v_model = H0*ds -H0*intercept
    plt.plot(ds, v_model, 'k-', alpha=0.05)

plt.errorbar(d, v,  xerr=d_err, fmt='.', capsize=2,color='k')
plt.xlim(0, ds.max())

plt.xlabel('Distance (Mpc)')
plt.ylabel('Velocity (km/s)')
# Out:
# Text(0, 0.5, 'Velocity (km/s)')

# %% [markdown]
# ## Now let's do the Pantheon dataset!

# %%
ddir = '../data/'
fname = 'Pantheon.dat'

data = Table.read(ddir+fname, format='ascii')

# %%
print(data.keys())

z = data['zCMB']
z_err = data['zCMBERR']
mb = data['MU_SH0ES'] # distance modulus
mb_err = data['MU_SH0ES_ERR_DIAG']

cut = (z > 0.02) & (z < 0.06) & (z_err < 0.005)
z = z[cut]
z_err = z_err[cut]
mb = mb[cut]
mb_err = mb_err[cut]

# distance
d = 10**((mb-25)/5) # Mpc
d_err = d * np.log(10) * mb_err / 5
# Out:
# ['CID', 'IDSURVEY', 'zHD', 'zHDERR', 'zCMB', 'zCMBERR', 'zHEL', 'zHELERR', 'm_b_corr', 'm_b_corr_err_DIAG', 'MU_SH0ES', 'MU_SH0ES_ERR_DIAG', 'CEPH_DIST', 'IS_CALIBRATOR', 'USED_IN_SH0ES_HF', 'c', 'cERR', 'x1', 'x1ERR', 'mB', 'mBERR', 'x0', 'x0ERR', 'COV_x1_c', 'COV_x1_x0', 'COV_c_x0', 'RA', 'DEC', 'HOST_RA', 'HOST_DEC', 'HOST_ANGSEP', 'VPEC', 'VPECERR', 'MWEBV', 'HOST_LOGMASS', 'HOST_LOGMASS_ERR', 'PKMJD', 'PKMJDERR', 'NDOF', 'FITCHI2', 'FITPROB', 'm_b_corr_err_RAW', 'm_b_corr_err_VPEC', 'biasCor_m_b', 'biasCorErr_m_b', 'biasCor_m_b_COVSCALE', 'biasCor_m_b_COVADD']

# %%
plt.errorbar(z, d, yerr=d_err, xerr=z_err, fmt='.', capsize=2)
zs = np.linspace(0, 0.0602, 100)
# Hubble's law
# H0 = 75 km/s/Mpc
# z to velocity
c = 299792.458 # km/s
# Relativistic doppler shift
vs = c * (zs / (1 + zs))
model = vs / 68
plt.plot(zs, model, 'k--')
plt.xlim(0.018,0.0602)
# Out:
# (0.018, 0.0602)

# %%
def lnprior(H0):
    if 0 < H0 < 200:
        return 0.0
    return -np.inf

def model(H0,intercept,z):
    v = c * (z / (1 + z))
    return v/H0 + intercept

def lnlike(H0, intercept, z, d, d_err):
    return -0.5 * np.sum((d-model(H0,intercept,z))**2 / d_err**2)

def lnprob(theta, z, d, d_err):
    H0, intercept = theta
    lp = lnprior(H0)
    if not np.isfinite(lp):
        return -np.inf
    return lp + lnlike(H0,intercept, z, d, d_err)

# %%
# sample with emcee
ndim, nwalkers = 2, 100
pos = np.array([68,0]) + 1e-4 * np.random.randn(100, 2)
sampler = emcee.EnsembleSampler(nwalkers, ndim, lnprob, args=(z, d, d_err))
burnin = sampler.run_mcmc(pos, 500, progress=True)
sampler.reset()
sampler.run_mcmc(burnin, 1000, progress=True);
# Out:
# 100%|██████████| 500/500 [00:02<00:00, 179.14it/s]
# 100%|██████████| 1000/1000 [00:05<00:00, 175.40it/s]

# %%
# chainconsumer

samples = sampler.get_chain(flat=True)
chain = Chain.from_emcee(sampler, ['H0','intercept'], "an emcee chain", discard=200, thin=2, color="indigo")
consumer = ChainConsumer().add_chain(chain)

fig = consumer.plotter.plot()

# %%
samples
# Out:
# array([[ 61.9459475 , -14.30027283],
#        [ 64.19977437,  -8.99133237],
#        [ 62.42457418, -13.67757819],
#        ...,
#        [ 62.92590856, -11.60454947],
#        [ 64.42631959,  -8.66405299],
#        [ 64.80099323,  -8.58095108]])

# %%
samples.shape
# Out:
# (100000, 2)

# %%
# plot posterior predictive model

# choose values

inds = np.random.choice(np.arange(samples.shape[0]), 50)
zs = np.linspace(0, 0.061, 100)

for ind in inds:
    H0 = samples[ind,0]
    intercept = samples[ind,1]

    d_model = model(H0, intercept, zs)
    plt.plot(zs, d_model, 'k-', alpha=0.05)

plt.errorbar(z, d, yerr=d_err, xerr=z_err, fmt='.', capsize=2)
plt.xlim(0.0,0.0602)
# Out:
# (0.0, 0.0602)

# %%
chi2 = -2 * lnlike(69,0, z, d, d_err)
chi2_red = chi2 / (len(z) - 1)
chi2_red
# Out:
# 0.5449476100503943
